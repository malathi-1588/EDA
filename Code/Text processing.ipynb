# %%
import re
pattern = "\d\d\d\d\d-\d\d\d\d\d"
c = re.compile(pattern)

# %%
s = "ph no is 88888-99999 and another num is 87878-78787"

# %%
y = c.search(s)
print(y.group())
# Out:
# 88888-99999

# %%
z = c.findall(s)
z
# Out:
# ['88888-99999', '87878-78787']

# %%
#any emojis and special symbols will be removed since they are no included in re.compile
#for extracting only those type re.compile(r'[^a-zA-Z0-9]) ^ is like negation so every character other than a-z A-Z and 0-9 are given
s = 'Python123@#😂'
c = re.compile(r'[^a-zA-Z0-9]')
#s1 = c.match(s)
#s1 = c.match(s)
s1 = c.findall(s)
print(s1)
# Out:
# ['@', '#', '😂']

# %%
''.join(s1)
# Out:
# '@#😂'

# %%
s = 'HelloWorld'
print(re.sub('(\w)([A-Z])','\\1 \\2',s))
# Out:
# Hello World

# %%
pattern = "^a(b*)$" # 'a' followed by 0 or more occurences of b a, ab, abbb, abbbbb etc
pattern2 = "^a(b+)$" # 'a' followed by 1 or more occurences of b ab, abb , etc
s = 'a'
re.search(pattern, s)
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
pattern3 = "^[A-Z]+[a-z*]+$"
s = 'Hi'
re.search(pattern3, s)
# Out:
# <re.Match object; span=(0, 2), match='Hi'>

# %% [markdown]
# 1. static website - websites with no user interaction example news websites the content may change but there is no interaction
#    b/w the user and the website i.e., no login page, no user data, etc
#
# 2. facebook, twitter etc are all not static
#
# 3. APIs are used to extract data from non-static websites
#
# 4. there is no need for an API for extracting data from static websites

# %%
url = 'https://www.inshorts.com/en/read/sports'
category = url.split('/')[-1]
print(category)
# ?re
# Out:
# sports

# %%
import requests
from bs4 import BeautifulSoup
data = requests.get(url)
print(data)
print(data.content)
# Out:
# <Response [200]>
# ...

# %%
soup = BeautifulSoup(data.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
# ...

# %%
news_data = [
    {'headline':headline.find('span', attrs = {'itemprop':'headline'}).string,
    'article':article.find('div', attrs = {'itemprop':'articlebody'}).string
    }
    for headline, article in zip(soup.find_all(
    'div', class_ = ["news-card-title news-right-box"]),
soup.find_all('div', class_ = ["news-card-content news-right-box"]))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16224\279757671.py in <module>
# ----> 1 news_data = [
#       2     {'headline':headline.find('span', attrs = {'itemprop':'headline'}).string,
#       3     'article':article.find('div', attrs = {'itemprop':'articlebody'}).string
#       4     }
#       5     for headline, article in zip(soup.find_all(
#
# ~\AppData\Local\Temp\ipykernel_16224\279757671.py in <listcomp>(.0)
#       1 news_data = [
#       2     {'headline':headline.find('span', attrs = {'itemprop':'headline'}).string,
# ----> 3     'article':article.find('div', attrs = {'itemprop':'articlebody'}).string
#       4     }
#       5     for headline, article in zip(soup.find_all(
#
# AttributeError: 'NoneType' object has no attribute 'string'
