# %%
import pandas as pd
import numpy as np

data = pd.read_csv(r'D:\Malathi\EDA\BirthMonthsData.csv')

# %%
data.head(20)
# Out:
#    Country or Area  Year   Area      Month  \
# 0    Åland Islands  2019  Total      Total
# 1    Åland Islands  2019  Total    January
# 2    Åland Islands  2019  Total   February
# 3    Åland Islands  2019  Total      March
# 4    Åland Islands  2019  Total      April
# 5    Åland Islands  2019  Total        May
# 6    Åland Islands  2019  Total       June
# 7    Åland Islands  2019  Total       July
# 8    Åland Islands  2019  Total     August
# 9    Åland Islands  2019  Total  September
# 10   Åland Islands  2019  Total    October
# 11   Åland Islands  2019  Total   November
# 12   Åland Islands  2019  Total   December
# 13   Åland Islands  2018  Total      Total
# 14   Åland Islands  2018  Total    January
# 15   Åland Islands  2018  Total   February
# 16   Åland Islands  2018  Total      March
# 17   Åland Islands  2018  Total      April
# 18   Åland Islands  2018  Total        May
# 19   Åland Islands  2018  Total       June
#
#                              Record Type             Reliability  \
# 0   Data tabulated by year of occurrence  Final figure, complete
# 1   Data tabulated by year of occurrence  Final figure, complete
# 2   Data tabulated by year of occurrence  Final figure, complete
# 3   Data tabulated by year of occurrence  Final figure, complete
# 4   Data tabulated by year of occurrence  Final figure, complete
# 5   Data tabulated by year of occurrence  Final figure, complete
# 6   Data tabulated by year of occurrence  Final figure, complete
# 7   Data tabulated by year of occurrence  Final figure, complete
# 8   Data tabulated by year of occurrence  Final figure, complete
# 9   Data tabulated by year of occurrence  Final figure, complete
# 10  Data tabulated by year of occurrence  Final figure, complete
# 11  Data tabulated by year of occurrence  Final figure, complete
# 12  Data tabulated by year of occurrence  Final figure, complete
# 13  Data tabulated by year of occurrence  Final figure, complete
# 14  Data tabulated by year of occurrence  Final figure, complete
# 15  Data tabulated by year of occurrence  Final figure, complete
# 16  Data tabulated by year of occurrence  Final figure, complete
# 17  Data tabulated by year of occurrence  Final figure, complete
# 18  Data tabulated by year of occurrence  Final figure, complete
# 19  Data tabulated by year of occurrence  Final figure, complete
#
#     Number_of_Births
# 0              267.0
# 1               28.0
# 2               24.0
# 3               26.0
# 4               16.0
# 5               31.0
# 6               21.0
# 7               18.0
# 8               18.0
# 9               24.0
# 10              20.0
# 11              17.0
# 12              24.0
# 13             280.0
# 14              16.0
# 15              27.0
# 16              20.0
# 17              19.0
# 18              25.0
# 19              23.0

# %%
data = data.set_index(data["Month"])
data = data.drop("Total")

# %%
data["Country or Area"].unique()
# Out:
# array(['Åland Islands', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Bermuda',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Cabo Verde', 'Canada', 'Cayman Islands', 'Chile',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'Cook Islands',
#        'Costa Rica', 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        'Denmark', 'Egypt', 'El Salvador', 'Estonia',
#        'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland',
#        'France', 'French Guiana', 'French Polynesia', 'Georgia',
#        'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guyana', 'Hungary',
#        'Iceland', 'Iran (Islamic Republic of)', 'Ireland', 'Isle of Man',
#        'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan',
#        'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Latvia', 'Lebanon', 'Libya',
#        'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Malta', 'Martinique', 'Mauritius', 'Mayotte',
#        'Mexico', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco',
#        'Netherlands', 'New Caledonia', 'New Zealand', 'Niue',
#        'Norfolk Island', 'North Macedonia', 'Norway', 'Oman', 'Pakistan',
#        'Palau', 'Panama', 'Peru', 'Philippines', 'Poland', 'Portugal',
#        'Puerto Rico', 'Qatar', 'Republic of Korea', 'Republic of Moldova',
#        'Reunion', 'Romania', 'Russian Federation',
#        'Saint Helena ex. dep.', 'Saint Helena: Ascension',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Saint-Martin (French part)', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Serbia', 'Seychelles', 'Singapore',
#        'Slovakia', 'Slovenia', 'South Africa', 'Spain', 'Sri Lanka',
#        'State of Palestine', 'Suriname', 'Sweden', 'Switzerland',
#        'Tajikistan', 'Thailand', 'Tonga', 'Trinidad and Tobago',
#        'Tunisia', 'Turkey', 'Turks and Caicos Islands', 'Ukraine',
#        'United Arab Emirates',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United States of America', 'United States Virgin Islands',
#        'Uruguay', 'Uzbekistan', 'Venezuela (Bolivarian Republic of)',
#        'Wallis and Futuna Islands'], dtype=object)

# %%
data = data.set_index(data["Country or Area"])

# %%
data = data.drop(['Albania', 'Algeria', 'American Samoa', 'Andorra',
       'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
       'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
       'Barbados', 'Belarus', 'Belgium', 'Bermuda',
       'Bosnia and Herzegovina', 'Botswana', 'Brazil',
       'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
       'Cabo Verde', 'Canada', 'Cayman Islands', 'Chile',
       'China, Hong Kong SAR', 'China, Macao SAR', 'Cook Islands',
       'Costa Rica', 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
       'Denmark', 'Egypt', 'El Salvador', 'Estonia',
       'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland',
       'France', 'French Guiana', 'French Polynesia', 'Georgia',
       'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
       'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guyana', 'Hungary',
       'Iceland', 'Iran (Islamic Republic of)', 'Ireland', 'Isle of Man',
       'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan',
       'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Latvia', 'Lebanon', 'Libya',
       'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malawi', 'Malaysia',
       'Maldives', 'Mali', 'Malta', 'Martinique', 'Mauritius', 'Mayotte',
       'Mexico', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco',
       'Netherlands', 'New Caledonia', 'New Zealand', 'Niue',
       'Norfolk Island', 'North Macedonia', 'Norway', 'Oman', 'Pakistan',
       'Palau', 'Panama', 'Peru', 'Philippines', 'Poland', 'Portugal',
       'Puerto Rico', 'Qatar', 'Republic of Korea', 'Republic of Moldova',
       'Reunion', 'Romania', 'Russian Federation',
       'Saint Helena ex. dep.', 'Saint Helena: Ascension',
       'Saint Kitts and Nevis', 'Saint Lucia',
       'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
       'Saint-Martin (French part)', 'Samoa', 'San Marino',
       'Sao Tome and Principe', 'Serbia', 'Seychelles', 'Singapore',
       'Slovakia', 'Slovenia', 'South Africa', 'Spain', 'Sri Lanka',
       'State of Palestine', 'Suriname', 'Sweden', 'Switzerland',
       'Tajikistan', 'Thailand', 'Tonga', 'Trinidad and Tobago',
       'Tunisia', 'Turkey', 'Turks and Caicos Islands', 'Ukraine',
       'United Arab Emirates',
       'United Kingdom of Great Britain and Northern Ireland',
       'United States of America', 'United States Virgin Islands',
       'Uruguay', 'Uzbekistan', 'Venezuela (Bolivarian Republic of)',
       'Wallis and Futuna Islands'])

# %%
data
# Out:
#                 Country or Area  Year   Area      Month  \
# Country or Area
# Åland Islands     Åland Islands  2019  Total    January
# Åland Islands     Åland Islands  2019  Total   February
# Åland Islands     Åland Islands  2019  Total      March
# Åland Islands     Åland Islands  2019  Total      April
# Åland Islands     Åland Islands  2019  Total        May
# ...                         ...   ...    ...        ...
# Åland Islands     Åland Islands  2006  Total     August
# Åland Islands     Åland Islands  2006  Total  September
# Åland Islands     Åland Islands  2006  Total    October
# Åland Islands     Åland Islands  2006  Total   November
# Åland Islands     Åland Islands  2006  Total   December
#
#                                           Record Type             Reliability  \
# Country or Area
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# ...                                               ...                     ...
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
#
#                  Number_of_Births
# Country or Area
# Åland Islands                28.0
# Åland Islands                24.0
# Åland Islands                26.0
# Åland Islands                16.0
# Åland Islands                31.0
# ...                           ...
# Åland Islands                24.0
# Åland Islands                27.0
# Åland Islands                31.0
# Åland Islands                20.0
# Åland Islands                25.0
#
# [132 rows x 7 columns]

# %%
d = {'January':'1', 'February':'2', 'March':'3', 'April':'4', 'May':'5', 'June':'6', 'July' :'7', 'August':'8', 
     'September':'9', 'October':'10', 'November':'11', 'December':'12'}

# %%
data["Month_num"]= data["Month"].map(d)

# %%
data
# Out:
#                 Country or Area  Year   Area      Month  \
# Country or Area
# Åland Islands     Åland Islands  2019  Total    January
# Åland Islands     Åland Islands  2019  Total   February
# Åland Islands     Åland Islands  2019  Total      March
# Åland Islands     Åland Islands  2019  Total      April
# Åland Islands     Åland Islands  2019  Total        May
# ...                         ...   ...    ...        ...
# Åland Islands     Åland Islands  2006  Total     August
# Åland Islands     Åland Islands  2006  Total  September
# Åland Islands     Åland Islands  2006  Total    October
# Åland Islands     Åland Islands  2006  Total   November
# Åland Islands     Åland Islands  2006  Total   December
#
#                                           Record Type             Reliability  \
# Country or Area
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# ...                                               ...                     ...
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
# Åland Islands    Data tabulated by year of occurrence  Final figure, complete
#
#                  Number_of_Births Month_num
# Country or Area
# Åland Islands                28.0         1
# Åland Islands                24.0         2
# Åland Islands                26.0         3
# Åland Islands                16.0         4
# Åland Islands                31.0         5
# ...                           ...       ...
# Åland Islands                24.0         8
# Åland Islands                27.0         9
# Åland Islands                31.0        10
# Åland Islands                20.0        11
# Åland Islands                25.0        12
#
# [132 rows x 8 columns]
